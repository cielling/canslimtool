# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as BSoup
from datetime import datetime
OK = True
BAD = False

# %%
def check_response_ok (response):
    import sys
    try:
        response.raise_for_status ()
        return OK
    except:
        f = open ("IBD_errors.log", "a")
        f.write ('{:%m/%d/%Y %H:%M:%S}'.format (datetime.now ()))
        f.write (" -- {}:\n\t\t{}".format (sys.exc_info ()[0], response.url))
        return BAD
    return BAD

# %%
def get_Ibd_rank_and_group (ticker):
    import numpy as np
    #return the result as a dict containing values for keys 'group', 'rank', 'leader'
    #if urls can not be accessed, returns an empty dict
    #if not all values are found, returns NaN for the missing values
    result = {}
    #first, search for the ticker symbol
    url_name1 = "http://myibd.investors.com/search/searchresults.aspx?Ntt={}".format (ticker.lower ())
    print ("url1: {}".format (url_name1))
    response1 = requests.get(url_name1)
    if (check_response_ok (response1)):
        #then, find the link to the stock's page by following down the chain of links
        #not sure if there is a more direct path to the stock's page
        soup1 =  BSoup (response1.content, "lxml")
        #if not a direct hit, there is a second step (hop) necessary
        url_name2 = soup1.find ("a", {"id": "ctl00_ctl00_secondaryContent_leftContent_SearchResultsMgrCtrl_didYouMeanCompanyRepeater_ctl00_didYouMeanLink"})
        print ("url2: {}".format (url_name2))
        if url_name2:
            response2 = requests.get (url_name2.get('href'))
            if (check_response_ok (response2)):
                soup2 = BSoup (response2.content, "lxml")
            #<span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-thor-industries-inc-tho.htm')">Thor Industries Inc</span>
                url_name3 = soup2.find ("span", {"id": "ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany"})
                print ("url3a: {}".format (url_name3))
            else:
                #---> what to do? return None, return NaN, set something to NaN?
                return result
        else:
            url_name3 = soup1.find ("span", {"id": "ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany"}) 
            print ("url3b: {}".format (url_name3))
        if not url_name3:
            return result
        tokens = url_name3.get ('onclick').split ("'")
        #---> check that tokens contains valid data
        if not tokens:
            return result
        for t in tokens:
            if "http://" in t:
                stock_link = t
                break
        response3 = requests.get (stock_link)
        if (check_response_ok (response3)):
            soup3 = BSoup (response3.content, "lxml")
            #finally got the page. Now find the ticker's group, ranking, and no.1 in that group
            market_group = soup3.find ("div", {"class": "spansubHead"})
            if (market_group):
                result["group"] = market_group.text
            else: 
                result["group"] = None

            #this span occurs only once, always contains the rank of the current ticker
            ticker_rank = soup3.find ("span", {"id":"ctl00_ctl00_secondaryContent_leftContent_GrpLeaders_ltlSymbolRank"})
            if (ticker_rank):
                result["rank"] = ticker_rank.text
            else:
                result["rank"] = np.nan

            #if ticker is not no. 1, the leader can be found in another anchor-tag inside the StockRolldiv
            #this will return None if current ticker is no. 1
            group_no1 = soup3.find ("a", {"class": "stockRoll"})
            if (group_no1):
                result["leader"] = group_no1.text
            else:
                result["leader"] = None
        else:
            return None
    
    #did not find a valid website on IBD for this ticker symbol
    return result

# %%
def add_Ibd_data (df):
    df["IBD_group"] = ""
    df["IBD_rank"] = 0
    for ticker in df.Symbol:
        ibd_data = get_Ibd_rank_and_group (ticker)
        print (ibd_data)
        if "group" in ibd_data:
            df["IBD_group"][df.Symbol == ticker] = ibd_data["group"]
        if "rank" in ibd_data:
            df["IBD_rank"][df.Symbol == ticker] = ibd_data["rank"]
    return df

# %%
def get_annual_sales_data (ticker):
    r = requests.get("https://eresearch.fidelity.com/eresearch/evaluate/fundamentals/financials.jhtml?stockspage=incomestatement&symbols={}&period=quarterly".format ("LRCX"))
    #now the html code is in the requests object:
    print (r.url)
    #BeautifulSoup can parse html code and convert into something usable
    soup =  BSoup (r.content, "lxml")
    #<th class="top-bottom-border col-96PX lft-border" scope="col"><span class="bold">2017</span> (06/30 - 03/31) </th>
    dt=soup.find ("table", {"class": "datatable-component"})
    #the summary attribute contains a short description of the table, check that this is the Net Income table
    #print ("net income" in dt.get("summary").lower ())
    #find all rows in this table; the first row contains the header with the dates
    allrows = dt.findChildren (name = "tr")
    firstrow=(allrows[0])
    #get the dates on the table:
    cols = []
    for f in firstrow.find_all ("th"):
        cols.append(f.text[7:-2])
    alldatarows = (allrows[1:])
    idxs= ["0",]
    for row in allrows[1:]:
        f = row.find ("th")
        if f:
            idxs.append (f.text)
    new_table = pd.DataFrame(columns=cols, index = idxs) # I know the size 

    row_marker = 0
    for row in dt.find_all('tr'):
        column_marker = 0
        columns = row.find_all('td')
        for column in columns:
            if not "Log in" in column.get_text():
                new_table.iat[row_marker,column_marker] = column.get_text()
            else:
                new_table.iat[row_marker, column_marker] = 0.0
            column_marker += 1
        row_marker += 1

    return (new_table)

# %%
if __name__ == "__main__":
    df = pd.read_excel ("screener_results.xls")
    df = add_Ibd_data (df)
# Out:
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=adbe
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-adobe-systems-inc-adbe.htm')">Adobe Systems Inc</span>
# {'group': 'Computer Sftwr-Desktop Group', 'rank': '2', 'leader': 'RHT'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=aeis
# /Users/234660/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/234660/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-advanced-energy-inds-aeis.htm')">Advanced Energy Inds</span>
# {'group': 'Elec-Semiconductor Equip Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=baba
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-alibaba-group-hldg-ads-baba.htm')">Alibaba Group Hldg Ads</span>
# {'group': 'Retail-Internet Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=algn
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-align-technology-inc-algn.htm')">Align Technology Inc</span>
# {'group': 'Medical-Products Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=ads
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-alliance-data-sys-corp-ads.htm')">Alliance Data Sys Corp</span>
# {'group': 'Finance-CrdtCard/PmtPr Group', 'rank': '18', 'leader': 'PYPL'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=alsn
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-allison-transmission-hld-alsn.htm')">Allison Transmission Hld</span>
# {'group': 'Auto/Truck-Original Eqp Group', 'rank': '13', 'leader': 'DAN'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=amp
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-ameriprise-financial-inc-amp.htm')">Ameriprise Financial Inc</span>
# {'group': 'Finance-Invest Bnk/Bkrs Group', 'rank': '7', 'leader': 'HLI'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=am
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-antero-midstream-ptnr-lp-am.htm')">Antero Midstream Ptnr LP</span>
# {'group': 'Oil&Gas-Transprt/Pipelne Group', 'rank': '3', 'leader': 'TGS'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=ait
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-applied-industrial-tech-ait.htm')">Applied Industrial Tech</span>
# {'group': 'Retail/Whlsle-Bldg Prds Group', 'rank': '9', 'leader': 'SITE'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=amat
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-applied-materials-inc-amat.htm')">Applied Materials Inc</span>
# {'group': 'Elec-Semiconductor Equip Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=aaoi
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-applied-optoelectronics-aaoi.htm')">Applied Optoelectronics</span>
# {'group': 'Telecom-Fiber Optics Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=agx
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-argan-inc-agx.htm')">Argan Inc</span>
# {'group': 'Bldg-Heavy Construction Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=anet
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-arista-networks-inc-anet.htm')">Arista Networks Inc</span>
# {'group': 'Computer-Networking Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=awi
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-armstrong-world-inds-awi.htm')">Armstrong World Inds</span>
# {'group': 'Bldg-Constr Prds/Misc Group', 'rank': '9', 'leader': 'BLD'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=asml
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-a-s-m-l-holding-nv-ny-asml.htm')">A S M L Holding N.V. NY</span>
# {'group': 'Elec-Semiconductor Equip Group', 'rank': '7', 'leader': 'AEIS'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=atri
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-atrion-corporation-atri.htm')">Atrion Corporation</span>
# {'group': 'Medical-Products Group', 'rank': '18', 'leader': 'ALGN'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=athm
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-autohome-inc-cl-a-ads-athm.htm')">Autohome Inc Cl A Ads</span>
# {'group': 'Internet-Content Group', 'rank': '6', 'leader': 'SINA'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=avy
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-avery-dennison-corp-avy.htm')">Avery Dennison Corp</span>
# {'group': 'Office Supplies Mfg Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=bnft
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-benefitfocus-inc-bnft.htm')">Benefitfocus Inc</span>
# {'group': 'Computer Sftwr-Medical Group', 'rank': '14', 'leader': 'TRHC'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=big
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-big-lots-inc-big.htm')">Big Lots Inc</span>
# {'group': 'Retail-Discount&Variety Group', 'rank': '5', 'leader': 'FIVE'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=bx
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-blackstone-group-lp-bx.htm')">Blackstone Group Lp</span>
# {'group': 'Finance-Investment Mgmt Group', 'rank': '15', 'leader': 'JP'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=byd
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-boyd-gaming-corp-byd.htm')">Boyd Gaming Corp</span>
# {'group': 'Leisure-Gaming/Equip Group', 'rank': '6', 'leader': 'MCRI'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=bpt
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-b-p-prudhoe-bay-rylty-tr-bpt.htm')">B P Prudhoe Bay Rylty Tr</span>
# {'group': 'Oil&Gas-Royalty Trust Group', 'rank': '3', 'leader': 'MTR'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=bco
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-brinks-co-bco.htm')">Brinks Co</span>
# {'group': 'Security/Sfty Group', 'rank': '5', 'leader': 'ITRN'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=brkr
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-bruker-corp-brkr.htm')">Bruker Corp</span>
# {'group': 'Elec-Scientific/Msrng Group', 'rank': '8', 'leader': 'COHR'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=cdns
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-cadence-design-systems-cdns.htm')">Cadence Design Systems</span>
# {'group': 'Computer Sftwr-Design Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=cp
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-canadian-pacific-railway-cp.htm')">Canadian Pacific Railway</span>
# {'group': 'Transportation-Rail Group', 'rank': '4', 'leader': 'CNI'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=cbg
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-c-b-r-e-group-inc-cbg.htm')">C B R E Group Inc</span>
# {'group': 'Real Estate Dvlpmt/Ops Group', 'rank': '5', 'leader': 'CTO'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=cdw
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-c-d-w-corp-cdw.htm')">C D W Corp</span>
# {'group': 'Computer-Tech Services Group', 'rank': '3', 'leader': 'EPAM'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=celg
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-celgene-corp-celg.htm')">Celgene Corp</span>
# {'group': 'Medical-Biomed/Biotech Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=crl
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-charles-river-labs-intl-crl.htm')">Charles River Labs Intl</span>
# {'group': 'Medical-Research Eqp/Svc Group', 'rank': '6', 'leader': 'PRAH'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=ccf
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/amex-chase-corp-ccf.htm')">Chase Corp</span>
# {'group': 'Chemicals-Specialty Group', 'rank': '5', 'leader': 'FOE'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=crus
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-cirrus-logic-inc-crus.htm')">Cirrus Logic Inc</span>
# {'group': 'Elec-Semicondctor Fablss Group', 'rank': '16', 'leader': 'MPWR'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=coh
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-coach-inc-coh.htm')">Coach Inc</span>
# {'group': 'Apparel-Clothing Mfg Group', 'rank': '15', 'leader': 'GIL'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=cgnx
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-cognex-corp-cgnx.htm')">Cognex Corp</span>
# {'group': 'Elec-Scientific/Msrng Group', 'rank': '3', 'leader': 'COHR'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=ctsh
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-cognizant-tech-sol-cl-a-ctsh.htm')">Cognizant Tech Sol Cl A</span>
# {'group': 'Computer-Tech Services Group', 'rank': '4', 'leader': 'EPAM'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=cohr
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-coherent-inc-cohr.htm')">Coherent Inc</span>
# {'group': 'Elec-Scientific/Msrng Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=cmcsa
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-comcast-corp-cl-a-cmcsa.htm')">Comcast Corp Cl A</span>
# {'group': 'Telecom Svcs-Cable/Satl Group', 'rank': '2', 'leader': 'CCOI'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=csvi
# url2: None
# url3b: None
# {}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=cto
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/amex-consolidated-tomoka-land-cto.htm')">Consolidated Tomoka Land</span>
# {'group': 'Real Estate Dvlpmt/Ops Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=stz
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-constellation-brands-a-stz.htm')">Constellation Brands A</span>
# {'group': 'Beverages-Alcoholic Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=stz/b
# url2: None
# url3b: None
# {}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=cost
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-costco-wholesale-corp-cost.htm')">Costco Wholesale Corp</span>
# {'group': 'Retail-Major Disc Chains Group', 'rank': '2', 'leader': 'PSMT'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=dan
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-dana-incorporated-dan.htm')">Dana Incorporated</span>
# {'group': 'Auto/Truck-Original Eqp Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=play
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-dave-and-busters-ent-inc-play.htm')">Dave &amp; Buster's Ent Inc</span>
# {'group': 'Retail-Restaurants Group', 'rank': '15', 'leader': 'BOBE'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=dva
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-davita-healthcare-prtns-dva.htm')">Davita Healthcare Prtns</span>
# {'group': 'Medical-Outpnt/Hm Care Group', 'rank': '12', 'leader': 'RDNT'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=de
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-deere-and-co-de.htm')">Deere &amp; Co</span>
# {'group': 'Machinery-Farm Group', 'rank': '2', 'leader': 'ALG'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=dlph
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-delphi-automotive-plc-dlph.htm')">Delphi Automotive PLC</span>
# {'group': 'Auto/Truck-Original Eqp Group', 'rank': '7', 'leader': 'DAN'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=dlaky
# url2: None
# url3b: None
# {}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=dhil
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-diamond-hill-invt-group-dhil.htm')">Diamond Hill Invt Group</span>
# {'group': 'Finance-Investment Mgmt Group', 'rank': '12', 'leader': 'JP'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=dst
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-d-s-t-systems-inc-dst.htm')">D S T Systems Inc</span>
# {'group': 'Computer Sftwr-Financial Group', 'rank': '11', 'leader': 'GWRE'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=ew
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-edwards-lifesciences-cp-ew.htm')">Edwards Lifesciences Cp</span>
# {'group': 'Medical-Products Group', 'rank': '16', 'leader': 'ALGN'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=ea
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-electronic-arts-inc-ea.htm')">Electronic Arts Inc</span>
# {'group': 'Computer Sftwr-Gaming Group', 'rank': '3', 'leader': 'GRVY'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=efx
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-equifax-inc-efx.htm')">Equifax Inc</span>
# {'group': 'Financial Svcs-Specialty Group', 'rank': '15', 'leader': 'CBOE'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=esnt
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-essent-group-ltd-esnt.htm')">Essent Group Ltd</span>
# {'group': 'Finance-Mrtg&Rel Svc Group', 'rank': '3', 'leader': 'HF'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=el
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-estee-lauder-cos-cl-a-el.htm')">Estee Lauder Cos Cl A</span>
# {'group': 'Cosmetics/Personal Care Group', 'rank': '2', 'leader': 'NTRI'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=expo
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-exponent-inc-expo.htm')">Exponent Inc</span>
# {'group': 'Comml Svcs-Consulting Group', 'rank': '3', 'leader': 'NVEE'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=fb
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-facebook-inc-cl-a-fb.htm')">Facebook Inc Cl A</span>
# {'group': 'Internet-Content Group', 'rank': '3', 'leader': 'SINA'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=farm
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-farmer-brothers-co-farm.htm')">Farmer Brothers Co</span>
# {'group': 'Wholesale-Food Group', 'rank': '6', 'leader': 'PFGC'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=agm
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-federal-agric-mtg-cl-c-agm.htm')">Federal Agric Mtg Cl C</span>
# {'group': 'Finance-Mrtg&Rel Svc Group', 'rank': '4', 'leader': 'HF'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=agm/a
# url2: None
# url3b: None
# {}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=race
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-ferrari-n-v-race.htm')">Ferrari N V</span>
# {'group': 'Auto Manufacturers Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=fsv
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-firstservice-corporation-fsv.htm')">Firstservice Corporation</span>
# {'group': 'Real Estate Dvlpmt/Ops Group', 'rank': '6', 'leader': 'CTO'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=five
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-five-below-inc-five.htm')">Five Below Inc</span>
# {'group': 'Retail-Discount&Variety Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=fnd
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-floor-and-decor-hldgs-cl-a-fnd.htm')">Floor &amp; Decor Hldgs Cl A</span>
# {'group': 'Retail/Whlsle-Bldg Prds Group', 'rank': '7', 'leader': 'SITE'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=foxf
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-fox-factory-holding-corp-foxf.htm')">Fox Factory Holding Corp</span>
# {'group': 'Leisure-Products Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=gps
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-gap-inc-del-gps.htm')">Gap Inc Del</span>
# {'group': 'Retail-Apparel/Shoes/Acc Group', 'rank': '5', 'leader': 'PLCE'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=gnrc
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-generac-hldgs-inc-gnrc.htm')">Generac Hldgs Inc</span>
# {'group': 'Electrical-Power/Equipmt Group', 'rank': '5', 'leader': 'BWXT'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=brss
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-global-brass-and-copper-brss.htm')">Global Brass and Copper</span>
# {'group': 'Metal Proc & Fabrication Group', 'rank': '8', 'leader': 'B'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=gmlp
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-golar-lng-partners-lp-gmlp.htm')">Golar Lng Partners Lp</span>
# {'group': 'Oil&Gas-Transprt/Pipelne Group', 'rank': '5', 'leader': 'TGS'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=lope
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-grand-canyon-education-lope.htm')">Grand Canyon Education</span>
# {'group': 'Consumer Svcs-Education Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=omab
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-grupo-aero-cent-nort-ads-omab.htm')">Grupo Aero Cent Nort Ads</span>
# {'group': 'Real Estate Dvlpmt/Ops Group', 'rank': '21', 'leader': 'CTO'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=pac
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-grupo-aero-del-pac-ads-pac.htm')">Grupo Aero Del Pac Ads</span>
# {'group': 'Real Estate Dvlpmt/Ops Group', 'rank': '20', 'leader': 'CTO'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=asr
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-grupo-aeroportuario-adr-asr.htm')">Grupo Aeroportuario Adr</span>
# {'group': 'Real Estate Dvlpmt/Ops Group', 'rank': '11', 'leader': 'CTO'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=supv
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-grupo-superviel-cl-b-ads-supv.htm')">Grupo Superviel Cl B Ads</span>
# {'group': 'Banks-Foreign Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=hbi
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-hanesbrands-inc-hbi.htm')">Hanesbrands Inc</span>
# {'group': 'Apparel-Clothing Mfg Group', 'rank': '7', 'leader': 'GIL'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=has
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-hasbro-inc-has.htm')">Hasbro Inc</span>
# {'group': 'Leisure-Toys/Games/Hobby Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=hli
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-houlihan-lokey-inc-cl-a-hli.htm')">Houlihan Lokey Inc Cl A</span>
# {'group': 'Finance-Invest Bnk/Bkrs Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=hun
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-huntsman-corp-hun.htm')">Huntsman Corp</span>
# {'group': 'Chemicals-Basic Group', 'rank': '6', 'leader': 'DWDP'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=nsp
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-insperity-inc-nsp.htm')">Insperity Inc</span>
# {'group': 'Comml Svcs-Outsourcing Group', 'rank': '2', 'leader': 'CTAS'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=intc
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-intel-corp-intc.htm')">Intel Corp</span>
# {'group': 'Elec-Semiconductor Mfg Group', 'rank': '7', 'leader': 'ADI'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=idcc
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-interdigital-inc-idcc.htm')">Interdigital Inc</span>
# {'group': 'Elec-Misc Products Group', 'rank': '10', 'leader': 'OLED'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=ip
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-international-paper-co-ip.htm')">International Paper Co</span>
# {'group': 'Paper & Paper Products Group', 'rank': '9', 'leader': 'PKG'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=ipgp
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-i-p-g-photonics-corp-ipgp.htm')">I P G Photonics Corp</span>
# {'group': 'Elec-Scientific/Msrng Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=itrn
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-ituran-location-and-contrl-itrn.htm')">Ituran Location &amp; Contrl</span>
# {'group': 'Security/Sfty Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=lrcx
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-lam-research-corp-lrcx.htm')">Lam Research Corp</span>
# {'group': 'Elec-Semiconductor Equip Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=lvs
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-las-vegas-sands-corp-lvs.htm')">Las Vegas Sands Corp</span>
# {'group': 'Leisure-Gaming/Equip Group', 'rank': '4', 'leader': 'MCRI'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=lgih
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-l-g-i-homes-inc-lgih.htm')">L G I Homes Inc</span>
# {'group': 'Bldg-Resident/Comml Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=leco
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-lincoln-electric-hldgs-leco.htm')">Lincoln Electric Hldgs</span>
# {'group': 'Machinery-Tools & Rel Group', 'rank': '2', 'leader': 'XYL'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=lfus
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-littelfuse-inc-lfus.htm')">Littelfuse Inc</span>
# {'group': 'Electronic-Parts Group', 'rank': '2', 'leader': 'KEM'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=logi
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-logitech-intl-sa-logi.htm')">Logitech Intl Sa</span>
# {'group': 'Computer-Hardware/Perip Group', 'rank': '2', 'leader': 'DVMT'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=lpx
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-louisiana-pacific-corp-lpx.htm')">Louisiana Pacific Corp</span>
# {'group': 'Bldg-Wood Prds Group', 'rank': '2', 'leader': 'OSB'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=low
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-lowes-companies-inc-low.htm')">Lowes Companies Inc</span>
# {'group': 'Retail/Whlsle-Bldg Prds Group', 'rank': '6', 'leader': 'SITE'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=lpla
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-l-p-l-financial-holdings-lpla.htm')">L P L Financial Holdings</span>
# {'group': 'Finance-Invest Bnk/Bkrs Group', 'rank': '13', 'leader': 'HLI'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=mbuu
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-malibu-boats-inc-cl-a-mbuu.htm')">Malibu Boats Inc Cl A</span>
# {'group': 'Leisure-Products Group', 'rank': '2', 'leader': 'FOXF'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=masi
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-masimo-corp-masi.htm')">Masimo Corp</span>
# {'group': 'Medical-Systems/Equip Group', 'rank': '7', 'leader': 'CMD'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=mxim
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-maxim-integrated-prods-mxim.htm')">Maxim Integrated Prods</span>
# {'group': 'Elec-Semicondctor Fablss Group', 'rank': '7', 'leader': 'MPWR'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=mcft
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-m-c-b-c-holdings-inc-mcft.htm')">M C B C Holdings Inc</span>
# {'group': 'Leisure-Products Group', 'rank': '4', 'leader': 'FOXF'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=med
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-medifast-inc-med.htm')">Medifast Inc</span>
# {'group': 'Cosmetics/Personal Care Group', 'rank': '3', 'leader': 'NTRI'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=mhgu
# url2: None
# url3b: None
# {}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=msb
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-mesabi-trust-msb.htm')">Mesabi Trust</span>
# {'group': 'Mining-Metal Ores Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=mtd
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-mettler-toledo-intl-inc-mtd.htm')">Mettler Toledo Intl Inc</span>
# {'group': 'Elec-Scientific/Msrng Group', 'rank': '5', 'leader': 'COHR'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=msft
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-microsoft-corp-msft.htm')">Microsoft Corp</span>
# {'group': 'Computer Sftwr-Desktop Group', 'rank': '3', 'leader': 'RHT'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=mksi
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-m-k-s-instruments-inc-mksi.htm')">M K S Instruments Inc</span>
# {'group': 'Elec-Semiconductor Equip Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=mc
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-moelis-and-company-cl-a-mc.htm')">Moelis &amp; Company Cl A</span>
# {'group': 'Finance-Invest Bnk/Bkrs Group', 'rank': '3', 'leader': 'HLI'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=tap/a
# url2: None
# url3b: None
# {}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=tap
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-molson-coors-brewing-b-tap.htm')">Molson Coors Brewing B</span>
# {'group': 'Beverages-Alcoholic Group', 'rank': '10', 'leader': 'STZ'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=momo
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-momo-inc-ads-cl-a-momo.htm')">Momo Inc Ads Cl A</span>
# {'group': 'Internet-Content Group', 'rank': '17', 'leader': 'SINA'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=mnst
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-monster-beverage-corp-mnst.htm')">Monster Beverage Corp</span>
# {'group': 'Beverages-Non-Alcoholic Group', 'rank': '3', 'leader': 'FIZZ'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=morn
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-morningstar-inc-morn.htm')">Morningstar Inc</span>
# {'group': 'Comml Svcs-Market Rsrch Group', 'rank': '8', 'leader': 'SPGI'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=msci
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-m-s-c-i-inc-msci.htm')">M S C I Inc</span>
# {'group': 'Financial Svcs-Specialty Group', 'rank': '4', 'leader': 'CBOE'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=nano
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-nanometrics-inc-nano.htm')">Nanometrics Inc</span>
# {'group': 'Elec-Semiconductor Equip Group', 'rank': '22', 'leader': 'AEIS'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=fizz
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-national-beverage-corp-fizz.htm')">National Beverage Corp</span>
# {'group': 'Beverages-Non-Alcoholic Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=nrcia
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-national-research-cl-a-nrcia.htm')">National Research Cl A</span>
# {'group': 'Comml Svcs-Healthcare Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=ncr
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-n-c-r-corp-ncr.htm')">N C R Corp</span>
# {'group': 'Computer-Integrated Syst Group', 'rank': '3', 'leader': 'PAR'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=ntap
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-netapp-inc-ntap.htm')">Netapp Inc</span>
# {'group': 'Computer-Data Storage Group', 'rank': '2', 'leader': 'MU'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=edu
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-new-orientl-eduandtech-ads-edu.htm')">New Orientl Edu&amp;Tech Ads</span>
# {'group': 'Consumer Svcs-Education Group', 'rank': '4', 'leader': 'LOPE'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=nblx
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-noble-midstream-prtns-lp-nblx.htm')">Noble Midstream Prtns Lp</span>
# {'group': 'Oil&Gas-Transprt/Pipelne Group', 'rank': '21', 'leader': 'TGS'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=osb
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-norbord-inc-osb.htm')">Norbord Inc</span>
# {'group': 'Bldg-Wood Prds Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=nsh
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-nustar-gp-holdings-llc-nsh.htm')">Nustar Gp Holdings Llc</span>
# {'group': 'Oil&Gas-Refining/Mktg Group', 'rank': '20', 'leader': 'PARR'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=ntri
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-nutrisystem-inc-ntri.htm')">Nutrisystem Inc</span>
# {'group': 'Cosmetics/Personal Care Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=nvda
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-nvidia-corp-nvda.htm')">Nvidia Corp</span>
# {'group': 'Elec-Semicondctor Fablss Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=nvr
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-n-v-r-inc-nvr.htm')">N V R Inc</span>
# {'group': 'Bldg-Resident/Comml Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=oak
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-oaktree-capital-grp-cl-a-oak.htm')">Oaktree Capital Grp Cl A</span>
# ...
# {'group': 'Computer-Data Storage Group', 'rank': '8', 'leader': 'MU'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=see
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-sealed-air-corp-see.htm')">Sealed Air Corp</span>
# {'group': 'Containers/Packaging Group', 'rank': '13', 'leader': 'BERY'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=sci
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-service-corp-intl-sci.htm')">Service Corp Intl</span>
# {'group': 'Funeral Svcs & Rel Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=serv
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-servicemaster-glb-hldgs-serv.htm')">Servicemaster Glb Hldgs</span>
# {'group': 'Bldg-Maintenance & Svc Group', 'rank': '3', 'leader': 'IBP'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=site
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-siteone-landscape-supply-site.htm')">SiteOne Landscape Supply</span>
# {'group': 'Retail/Whlsle-Bldg Prds Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=swks
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-skyworks-solutions-inc-swks.htm')">Skyworks Solutions Inc</span>
# {'group': 'Elec-Semiconductor Mfg Group', 'rank': '9', 'leader': 'ADI'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=stmp
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-stampscom-inc-stmp.htm')">Stamps.Com Inc</span>
# {'group': 'Retail-Internet Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=snc
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-state-national-companies-snc.htm')">State National Companies</span>
# {'group': 'Insurance-Prop/Cas/Titl Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=supn
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-supernus-pharmaceuticals-supn.htm')">Supernus Pharmaceuticals</span>
# {'group': 'Medical-Biomed/Biotech Group', 'rank': '5', 'leader': 'CELG'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=syy
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-sysco-corp-syy.htm')">Sysco Corp</span>
# {'group': 'Wholesale-Food Group', 'rank': '2', 'leader': 'PFGC'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=trow
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-price-t-rowe-group-inc-trow.htm')">Price T Rowe Group Inc</span>
# {'group': 'Finance-Investment Mgmt Group', 'rank': '3', 'leader': 'JP'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=tal
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-t-a-l-education-gp-a-ads-tal.htm')">T A L Education Gp A Ads</span>
# {'group': 'Consumer Svcs-Education Group', 'rank': '2', 'leader': 'LOPE'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=teo
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-telecom-argent-s-a-ads-teo.htm')">Telecom Argent S A Ads</span>
# {'group': 'Telecom Svcs- Foreign Group', 'rank': '2', 'leader': 'NTL'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=tpx
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-tempur-sealy-intl-inc-tpx.htm')">Tempur Sealy Intl Inc</span>
# {'group': 'Hsehold/Office Furniture Group', 'rank': '5', 'leader': 'HOFT'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=tx
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-ternium-sa-adr-tx.htm')">Ternium Sa Adr</span>
# {'group': 'Steel-Producers Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=txn
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-texas-instruments-txn.htm')">Texas Instruments</span>
# {'group': 'Elec-Semiconductor Mfg Group', 'rank': '3', 'leader': 'ADI'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=tpl
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-texas-pacific-land-trust-tpl.htm')">Texas Pacific Land Trust</span>
# {'group': 'Real Estate Dvlpmt/Ops Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=tho
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-thor-industries-inc-tho.htm')">Thor Industries Inc</span>
# {'group': 'Bldg-Mobile/Mfg & Rv Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=tss
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-total-system-services-tss.htm')">Total System Services</span>
# {'group': 'Finance-CrdtCard/PmtPr Group', 'rank': '8', 'leader': 'PYPL'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=ttd
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-the-trade-desk-inc-cl-a-ttd.htm')">The Trade Desk Inc Cl A</span>
# {'group': 'Comml Svcs-Advertising Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=tnet
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-trinet-group-inc-tnet.htm')">Trinet Group Inc</span>
# {'group': 'Comml Svcs-Outsourcing Group', 'rank': '8', 'leader': 'CTAS'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=tcx
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-tucows-inc-cl-a-tcx.htm')">Tucows Inc Cl A</span>
# {'group': 'Internet-Network Sltns Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=ulta
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-ulta-beauty-inc-ulta.htm')">Ulta Beauty Inc</span>
# {'group': 'Retail-Specialty Group', 'rank': '4', 'leader': 'PETZ'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=unh
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-unitedhealth-group-inc-unh.htm')">Unitedhealth Group Inc</span>
# {'group': 'Medical-Managed Care Group', 'rank': '3', 'leader': 'CNC'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=veev
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-veeva-systems-inc-cl-a-veev.htm')">Veeva Systems Inc Cl A</span>
# {'group': 'Computer Sftwr-Medical Group', 'rank': '2', 'leader': 'TRHC'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=vz
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-verizon-communications-vz.htm')">Verizon Communications</span>
# {'group': 'Telecom Svcs-Integrated Group', 'rank': '1', 'leader': None}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=vvi
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-viad-corp-vvi.htm')">Viad Corp</span>
# {'group': 'Comml Svcs-Advertising Group', 'rank': '2', 'leader': 'TTD'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=v
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-visa-inc-cl-a-v.htm')">Visa Inc Cl A</span>
# {'group': 'Finance-CrdtCard/PmtPr Group', 'rank': '3', 'leader': 'PYPL'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=vc
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-visteon-corporation-vc.htm')">Visteon Corporation</span>
# {'group': 'Auto/Truck-Original Eqp Group', 'rank': '5', 'leader': 'DAN'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=wmmvy
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/-walmart-de-mexico-adr-wmmvy.htm')">Wal-Mart De Mexico Adr</span>
# {'group': 'Retail-Major Disc Chains Group', 'rank': '5', 'leader': 'PSMT'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=wm
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-waste-management-inc-wm.htm')">Waste Management Inc</span>
# {'group': 'Pollution Control Group', 'rank': '4', 'leader': 'WCN'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=wb
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-weibo-corp-cl-a-ads-wb.htm')">Weibo Corp Cl A Ads</span>
# {'group': 'Internet-Content Group', 'rank': '3', 'leader': 'SINA'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=yumc
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nyse-yum-china-holdings-inc-yumc.htm')">Yum China Holdings Inc</span>
# {'group': 'Retail-Restaurants Group', 'rank': '8', 'leader': 'BOBE'}
# url1: http://myibd.investors.com/search/searchresults.aspx?Ntt=yy
# url2: None
# url3b: <span id="ctl00_ctl00_secondaryContent_leftContent_CustomContentCtrl_StockTwitMiniChart1_lblCompany" onclick="javascript:window.open('http://research.investors.com/stock-quotes/nasdaq-yy-inc-ads-yy.htm')">YY Inc Ads</span>
# {'group': 'Internet-Content Group', 'rank': '1', 'leader': None}
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/excel.py in __new__(cls, path, engine, **kwargs)
#     687                 try:
# --> 688                     engine = config.get_option('io.excel.%s.writer' % ext)
#     689                 except KeyError:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/config.py in __call__(self, *args, **kwds)
#     223     def __call__(self, *args, **kwds):
# --> 224         return self.__func__(*args, **kwds)
#     225
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/config.py in _get_option(pat, silent)
#      96 def _get_option(pat, silent=False):
# ---> 97     key = _get_single_key(pat, silent)
#      98
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/config.py in _get_single_key(pat, silent)
#      82             _warn_if_deprecated(pat)
# ---> 83         raise OptionError('No such keys(s): %r' % pat)
#      84     if len(keys) > 1:
#
# OptionError: "No such keys(s): 'io.excel.xsl.writer'"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-3b0986c8c073> in <module>()
#       2     df = pd.read_excel ("screener_results.xls")
#       3     df = add_Ibd_data (df)
# ----> 4     df.to_excel("screener_results_IBD.xsl")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    1422         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    1423                         startcol=startcol, freeze_panes=freeze_panes,
# -> 1424                         engine=engine)
#    1425
#    1426     def to_stata(self, fname, convert_dates=None, write_index=True,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     620         need_save = False
#     621         if isinstance(writer, string_types):
# --> 622             writer = ExcelWriter(writer, engine=engine)
#     623             need_save = True
#     624
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/excel.py in __new__(cls, path, engine, **kwargs)
#     689                 except KeyError:
#     690                     error = ValueError("No engine for filetype: '%s'" % ext)
# --> 691                     raise error
#     692             cls = get_writer(engine)
#     693
#
# ValueError: No engine for filetype: 'xsl'

# %%
    df.to_excel("screener_results_IBD.xls")
